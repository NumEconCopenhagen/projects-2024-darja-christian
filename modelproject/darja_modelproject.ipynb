# %%
import sympy as sm
from scipy import optimize
from darja_modelproject import stackelbergduopolClass
model = stackelbergduopolClass()

# %%
## inverse demand function
def P(x_1, x_2, a = 5, b = 1/4): ## local scope 
    c = a * 1/b
    if 0 <= (x_1 + x_2) <= c: 
        result =  a - b*(x_1 + x_2)
    else: ## can't have a negative price
        result = 0
    return result

# %%
P(2,2)
# Out:
# 4.0

# %%
P(15, 2, a = 4, b = 1/3)
# Out:
# 0

# %%
## defining cost functions for firm 1
def C_1(x_1, p = 2): 
   cost_1 = p*x_1
   return cost_1

# %%
## defining cost function for firm 2
def C_2(x_2, p = 1): ## local scope 
   cost_2 = p*x_2
   return cost_2

# %%
model.P(2,2) * 2 - model.C_1(2)
# Out:
# 4.0

# %%
model.objective_1(2)
# Out:
# -4

# %%
## numerical solution
## using solver 
model.neg_objective_1(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[186], line 3
#       1 ## numerical solution
#       2 ## using solver
# ----> 3 model.neg_objective_1(1)
#
# TypeError: stackelbergduopolClass.neg_objective_1() takes 1 positional argument but 2 were given
